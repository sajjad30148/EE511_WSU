# %% [markdown]
# # EE 511 - Homework 01
#
# ### Submitted by: Sajjad Uddin Mahmud

# %% [markdown]
# ### Part 1: Signal with no harmonics
# </br>
# <span style="color:#C3260C">
# a) Draw the following waveform:
#
# $ \begin{cases}
#     6 sin(\omega t + \pi /3) \; \; t < 0.1\\
#     10 sin(\omega t + \pi /3) \; \; t \geq 0.1
#     \end{cases}
# $
#
# Given that, $f=60$ Hz, and sampling frequency is 12 samples per cycle.
# </span>

# %%
## IMPORT PACKAGES
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
## PARAMETER INPUT
f = 60.0       # frequency in Hz
T = 1/f        # period in seconds
n = 12         # samples per cycle
dT = T/n       # delta T
A1 = 6.0       # amplitude of first signal
A2 = 10.0      # amplitude of second signal
A3 = 3.0       # amplitude of second harmonic
pi = np.pi

# %%
## PLOTTING INPUT SIGNAL
Time = np.arange(0,0.2,dT)
Voltage1 = []

for t in range(0,len(Time)):
    
    if Time[t] < 0.1:
        v = A1 * math.sin(2 * pi * f * Time[t] + pi/3) # first signal
    else:
        v = A2 * math.sin(2 * pi * f * Time[t] + pi/3) # second signal
        
    Voltage1.append(v)

plt.plot(Time,Voltage1,'green')
plt.title("Input Signal")
plt.xlabel("Time $(s)$")
plt.ylabel("Voltage $(V)$")
plt.legend(["Actual Signal"])
plt.grid()
plt.show()

# %% [markdown]
# <span style="color:#C3260C">
# b) Estimate the amplitude of the signal using Mann&Morrison algorithm
# </span>

# %% [markdown]
# In Mann & Morrison algorithm, it is assumed that the signal can be represented as a pure sinusoid whose amplitude as well as frequency is constant during the period under consideration [1].
# So for a signal $V = V_{p} sin(\omega_{0}t + \theta)$, $\\$
# $V_{p} = \sqrt{(V_{0})^2 + (\frac{V_{+1}-V_{-1}}{2\omega_{0} \Delta t})^2}$
#
# Here, sine component, $V_{p}sin\theta = V_{0}$ and cosine component $V_{p}cos\theta = \frac{V_{+1}-V_{-1}}{2\omega_{0} \Delta t}$

# %% [markdown]
# **Mann & Morrison Algorithm Function:**

# %%
# MANN & MORRISON ALGORITHM

def MannMorrison(sample,frequency,voltage):
    
    f0 = frequency # fundamental frequency
    n = sample
    
    T = 1/f0
    dT = T/n
    time = np.arange(0,0.2,dT)
    Vp = []

    for t in range(1, len(time)-1):
        sine_component = voltage[t]
        cosine_component = (voltage[t+1] - voltage[t-1])/(2*2*pi*f*dT)
        vp_temp = math.sqrt(sine_component**2 + cosine_component**2)
        Vp.append(vp_temp)

    Vp.append(vp_temp)

    # PLOT
    plt.plot(time,voltage,'green')
    plt.plot(time[1:len(time)],Vp,'r*-')
    plt.title("Mann&Morrison Algorithm for " + str(n) + " Samples")
    plt.xlabel("Time $(s)$")
    plt.ylabel("Voltage $(V)$")
    plt.legend(["Actual", "Estimated"])
    plt.grid()
    plt.show()

# %% [markdown]
# **Applying Mann & Morrison algorithm on given signal:**

# %%
MannMorrison(n,f,Voltage1)

# %% [markdown]
# <span style="color:#C3260C">
# c) Estimate the amplitude of the signal using Prodar algorithm
# </span>

# %% [markdown]
# ### Part 2: Signal with harmonics
# </br>
# <span style="color:#C3260C">
# Add second harmonic to the signal which means the signal becomes as follows:
#
# $ \begin{cases}
#     6 sin(\omega t + \pi /3) + 3 sin(2\omega t + \pi /3) \; \; t < 0.1\\
#     10 sin(\omega t + \pi /3) + 3 sin(2\omega t + \pi /3) \; \; t \geq 0.1
#     \end{cases}
# $
#
# Given that, $f=60$ Hz, and sampling frequency is 12 samples per cycle.
# </span>

# %% [markdown]
# Plotting the signal:

# %%
## PLOT
Time = np.arange(0,0.2,dT)
Voltage2 = []

for t in range(0,len(Time)):
    
    if Time[t] < 0.1:
        v = (A1 * math.sin(2 * pi * f * Time[t] + pi/3)) + (A3 * math.sin(2 * 2 * pi * f * Time[t] + pi/3)) # First signal
    else:
        v = A2 * math.sin(2 * pi * f * Time[t] + pi/3) + (A3 * math.sin(2 * 2 * pi * f * Time[t] + pi/3)) # Second signal
        
    Voltage2.append(v)

plt.plot(Time,Voltage2,'green')
plt.title("Input Signal with Harmonics")
plt.xlabel("Time in seconds")
plt.ylabel("Amplitude")
plt.legend(["Actual Signal"])
plt.grid()
plt.show()

# %%
# MANN & MORRISON ALGORITHM
MannMorrison(n,f,Voltage2)

# %% [markdown]
# #### Reference
#
# [1] S. R. Bhide, *Digital Power System Protection*, Delhi, 2014.
